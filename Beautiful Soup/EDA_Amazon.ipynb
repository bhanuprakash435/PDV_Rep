# %%
import pandas as pd
import numpy as np     
import matplotlib.pyplot as plt  
import seaborn as sns  
# %matplotlib inline

# %%
df = pd.read_csv('mobiledata.csv')

# %%
df.head()
# Out:
#                                          mobile_name mobile_price  \
# 0  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...       10,999
# 1  Samsung Galaxy M31 Prime Edition (Space Black,...       15,999
# 2  Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...       10,999
# 3  Redmi 9 Power (Electric Green, 4GB RAM, 64GB S...       10,999
# 4         Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage)        6,999
#
#         mobile_rating          mobile_delivery
# 0  3.7 out of 5 stars  FREE Delivery by Amazon
# 1  4.2 out of 5 stars  FREE Delivery by Amazon
# 2  3.7 out of 5 stars  FREE Delivery by Amazon
# 3  3.7 out of 5 stars  FREE Delivery by Amazon
# 4  4.1 out of 5 stars  FREE Delivery by Amazon

# %%
df.tail()
# Out:
#                                           mobile_name mobile_price  \
# 37  Samsung Galaxy M21 (Midnight Blue, 6GB RAM, 12...       14,499
# 38    Samsung Galaxy M02s (Red,4GB RAM, 64GB Storage)        9,999
# 39  Redmi Note 9 Pro (Champagne Gold, 4GB RAM, 64G...       12,999
# 40  Samsung EVO Plus 64GB microSDXC UHS-I 100MB/s ...          679
# 41  Redmi Note 9 (Shadow Black, 4GB RAM, 64GB Stor...       11,999
#
#          mobile_rating          mobile_delivery
# 37  4.4 out of 5 stars  FREE Delivery by Amazon
# 38  4.2 out of 5 stars  FREE Delivery by Amazon
# 39  3.7 out of 5 stars  FREE Delivery by Amazon
# 40  4.0 out of 5 stars  FREE Delivery by Amazon
# 41  3.7 out of 5 stars  FREE Delivery by Amazon

# %%
df.describe()
# Out:
#                                               mobile_name mobile_price  \
# count                                                  42           42
# unique                                                 42           20
# top     Redmi 9 Prime (Mint Green, 4GB RAM, 64GB Stora...        8,999
# freq                                                    1            4
#
#              mobile_rating          mobile_delivery
# count                   42                       42
# unique                   7                        1
# top     4.2 out of 5 stars  FREE Delivery by Amazon
# freq                    13                       42

# %%
df['mobile_rating'] = df['mobile_rating'].str.replace('out of', '')
df['mobile_rating'] = df['mobile_rating'].str.replace('5 stars', '')

df
# Out:
#                                           mobile_name mobile_price  \
# 0   Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...       10,999
# 1   Samsung Galaxy M31 Prime Edition (Space Black,...       15,999
# 2   Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...       10,999
# 3   Redmi 9 Power (Electric Green, 4GB RAM, 64GB S...       10,999
# 4          Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage)        6,999
# 5   Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...       12,999
# 6   Samsung Galaxy M31 (Ocean Blue, 6GB RAM, 128GB...       15,999
# 7   Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...       12,499
# 8   Redmi 9 Power (Fiery Red, 4GB RAM, 64GB Storag...       10,999
# 9   Redmi Note 9 Pro Max (Aurora Blue, 6GB RAM, 64...       14,999
# 10  Redmi Note 9 Pro (Interstellar Black, 4GB RAM,...       12,999
# 11     Redmi 9A (Nature Green, 2GB Ram, 32GB Storage)        6,999
# 12  Samsung Galaxy M31s (Mirage Blue, 6GB RAM, 128...       17,999
# ...
