# %%
import pandas
result = pandas.read_csv('amazon.csv')
result.head()
# Out:
#                      dtype                                               name  \
# 0                      NaN  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...
# 1  FREE Delivery by Amazon  Samsung Galaxy M31 Prime Edition (Space Black,...
# 2                      NaN  Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...
# 3  FREE Delivery by Amazon  Redmi 9 Power (Electric Green, 4GB RAM, 64GB S...
# 4                      NaN         Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage)
#
#     price             ratings
# 0  10,999        4 Stars & Up
# 1  15,999        3 Stars & Up
# 2  10,999        2 Stars & Up
# 3  10,999         1 Star & Up
# 4   6,999  3.7 out of 5 stars

# %%
import numpy as np
import pandas as pd
import os
import pandas_profiling
from pandas_profiling import ProfileReport

# %%
FILENAME = 'amazon.csv'
df = pd.read_csv(FILENAME)
df
# Out:
#                        dtype  \
# 0                        NaN
# 1    FREE Delivery by Amazon
# 2                        NaN
# 3    FREE Delivery by Amazon
# 4                        NaN
# ..                       ...
# 333                      NaN
# 334                   Get it
# 335     Thursday, January 28
# 336                        -
# 337     Saturday, January 30
#
#                                                   name   price  \
# 0    Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...  10,999
# 1    Samsung Galaxy M31 Prime Edition (Space Black,...  15,999
# 2    Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...  10,999
# 3    Redmi 9 Power (Electric Green, 4GB RAM, 64GB S...  10,999
# 4           Redmi 9A (Sea Blue, 2GB Ram, 32GB Storage)   6,999
# ..                                                 ...     ...
# 333             (Renewed) Samsung Galaxy Buds+ (Black)   6,999
# 334  (Renewed) Samsung Galaxy A30 (Black, 4GB RAM, ...  73,999
# 335  Samsung SM-G530,SM-G531F Grand Prime/J210F/J2 ...  13,828
# 336  Samsung Galaxy Watch Active 2 (Bluetooth, 44 m...     849
# 337  (Renewed) Redmi 7 (Eclipse Black, 2GB RAM, SD ...  17,945
#
#                 ratings
# 0          4 Stars & Up
# 1          3 Stars & Up
# 2          2 Stars & Up
# 3           1 Star & Up
# 4    3.7 out of 5 stars
# ..                  ...
# 333  4.2 out of 5 stars
# 334  4.0 out of 5 stars
# 335  2.8 out of 5 stars
# 336  2.9 out of 5 stars
# 337  3.4 out of 5 stars
#
# [338 rows x 4 columns]

# %%
price_list = df["price"].tolist()
price_list
# Out:
# ['10,999',
#  '15,999',
#  '10,999',
#  '10,999',
#  '6,999',
#  '12,999',
#  '15,999',
#  '12,499',
#  '10,999',
#  '14,999',
#  '12,999',
#  '6,999',
#  '17,999',
#  '6,999',
#  '8,999',
#  '12,499',
#  '9,999',
#  '14,999',
#  '22,999',
#  '9,499',
#  '17,999',
#  '17,499',
#  '13,999',
#  '22,999',
#  '8,999',
#  '7,999',
#  '13,999',
#  '12,999',
#  '24,999',
#  '17,499',
#  '7,499',
#  '8,999',
#  '15,999',
#  '8,999',
#  '9,999',
#  '24,999',
#  '14,999',
#  '7,499',
#  '19,999',
#  '11,999',
#  '14,499',
#  '9,999',
#  '12,999',
#  '679',
#  '11,999',
#  '11,999',
#  '9,999',
#  '11,999',
#  '5,999',
#  '1,329',
#  '14,499',
#  '1,199',
#  '19,999',
#  '1,299',
#  '14,999',
#  '11,999',
#  '13,999',
#  '8,999',
#  '10,999',
#  '699',
#  '399',
#  '10,999',
#  '17,499',
#  '4,999',
#  '8,999',
#  '13,999',
#  '4,999',
#  '1,895',
#  '419',
#  '7,999',
#  '2,299',
#  '399',
#  '1,709',
#  '11,999',
#  '11,999',
#  '9,999',
#  '1,709',
#  '5,999',
#  '1,330',
#  '1,398',
#  '1,709',
#  '949',
#  '1,150',
#  '7,499',
#  '9,499',
#  '499',
#  '9,999',
#  '1,199',
#  '1,375',
#  '13,999',
#  '13,999',
#  '12,999',
#  '1,449',
#  '8,999',
#  '12,999',
#  '1,299',
#  '2,999',
#  '1,449',
#  '22,999',
#  '15,499',
#  '19,990',
#  '15,499',
#  '4,999',
#  '18,625',
#  '27,499',
#  '11,999',
#  '12,999',
#  '12,999',
#  '549',
#  '699',
#  '1,449',
#  '8,989',
#  '2,490',
#  '799',
#  '6,840',
#  '22,999',
#  '14,999',
#  '18,999',
#  'price',
#  '10,999',
#  '15,999',
#  '10,999',
#  '10,999',
#  '6,999',
#  '12,999',
#  '15,999',
#  '12,499',
#  '10,999',
#  '14,999',
#  '12,999',
#  '6,999',
#  '17,999',
#  '6,999',
#  '8,999',
#  '12,499',
#  '9,999',
#  '14,999',
#  '22,999',
#  '9,499',
#  '17,999',
#  '17,499',
#  '13,999',
#  '22,999',
#  '8,999',
#  '7,999',
#  '13,999',
#  '12,999',
#  '24,999',
#  '17,499',
#  '7,499',
#  '8,999',
#  '15,999',
#  '8,999',
#  '9,999',
#  '24,999',
#  '14,999',
#  '7,499',
#  '19,999',
#  '11,999',
#  '14,499',
#  '9,999',
#  '12,999',
#  '679',
#  '11,999',
#  '11,999',
#  '9,999',
#  '11,999',
#  '5,999',
#  '1,329',
#  '14,499',
#  '1,199',
#  '19,999',
#  '1,299',
#  '14,999',
#  '11,999',
#  '13,999',
#  '8,999',
#  '10,999',
#  '699',
#  '399',
#  '10,999',
#  '17,499',
#  '4,999',
#  '8,999',
#  '13,999',
#  '4,999',
#  '1,895',
#  '419',
#  '7,999',
#  '2,299',
#  '399',
#  '1,709',
#  '11,999',
#  '11,999',
#  '9,999',
#  '1,709',
#  '5,999',
#  '1,330',
#  '1,398',
#  '1,709',
#  '949',
#  '1,150',
#  '7,499',
#  '9,499',
#  '499',
#  '9,999',
#  '1,199',
#  '1,375',
#  '13,999',
#  '13,999',
#  '12,999',
#  '1,449',
#  '8,999',
#  '12,999',
#  '1,299',
#  '1,299',
#  '2,999',
#  '1,449',
#  '22,999',
#  '15,499',
#  '19,990',
#  '15,499',
#  '4,999',
#  '18,625',
#  '27,499',
#  '11,999',
#  '12,999',
#  '12,999',
#  '549',
#  '699',
#  '1,449',
#  '8,989',
#  '2,490',
#  '799',
#  '6,840',
#  '22,999',
#  '14,999',
#  '18,999',
#  '3,399',
#  '24,499',
#  '18,999',
#  '1,06,989',
#  '7,999',
#  '18,249',
#  '2,340',
#  '14,999',
#  '24,499',
#  '31,003',
#  '18,999',
#  '11,990',
#  '14,999',
#  '8,999',
#  '6,999',
#  '344',
#  '1,749',
#  '38,999',
#  '8,990',
#  '36,999',
#  '35,300',
#  '2,699',
#  '16,999',
#  '16,999',
#  '11,990',
#  '8,348',
#  '910',
#  '1,05,999',
#  '24,499',
#  '8,348',
#  '2,340',
#  '9,990',
#  '26,990',
#  '34,850',
#  '22,990',
#  '999',
#  '9,999',
#  '15,999',
#  '28,990',
#  '21,999',
#  '36,999',
#  '459',
#  '499',
#  '28,990',
#  '917',
#  '17,499',
#  '16,498',
#  '40,999',
#  '69,999',
#  '599',
#  '499',
#  '9,897',
#  '16,498',
#  '919',
#  '1,299',
#  '22,999',
#  '829',
#  '1,05,999',
#  '12,999',
#  '40,999',
#  '835',
#  '37,999',
#  '17,499',
#  '40,999',
#  '40,999',
#  '27,499',
#  '989',
#  '28,999',
#  '11,999',
#  '7,299',
#  '640',
#  '17,499',
#  '10,990',
#  '38,999',
#  '7,343',
#  '38,998',
#  '17,999',
#  '1,05,999',
#  '1,04,999',
#  '39,990',
#  '24,490',
#  '21,990',
#  '82,989',
#  '18,600',
#  '1,148',
#  '707',
#  '82,989',
#  '40,999',
#  '1,49,998',
#  '9,499',
#  '18,799',
#  '19,150',
#  '5,593',
#  '699',
#  '23,990',
#  '6,999',
#  '73,999',
#  '13,828',
#  '849',
#  '17,945']

# %%
type(price_list)
# Out:
# list

# %%
df['price'] = df['price'].str.replace(',', '')
#price = df['price']
df['price'].astype(int)
#type(price)
#price = price.astype(int)
#int(price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-dde61cde60da> in <module>
#       1 df['price'] = df['price'].str.replace(',', '')
#       2 #price = df['price']
# ----> 3 df['price'].astype(int)
#       4 #type(price)
#       5 #price = price.astype(int)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5870         else:
#    5871             # else, only a single dtype is given
# -> 5872             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5873             return self._constructor(new_data).__finalize__(self, method="astype")
#    5874
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     629         self, dtype, copy: bool = False, errors: str = "raise"
#     630     ) -> "BlockManager":
# --> 631         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     632
#     633     def convert(
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     425                     applied = b.apply(f, **kwargs)
#     426                 else:
# --> 427                     applied = getattr(b, f)(**kwargs)
#     428             except (TypeError, NotImplementedError):
#     429                 if not ignore_failures:
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     671             vals1d = values.ravel()
#     672             try:
# --> 673                 values = astype_nansafe(vals1d, dtype, copy=True)
#     674             except (ValueError, TypeError):
#     675                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1072         # work around NumPy brokenness, #1987
#    1073         if np.issubdtype(dtype.type, np.integer):
# -> 1074             return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#    1075
#    1076         # if we have a datetime/timedelta array of objects
#
# pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'price'

# %%
if ((price > 1000) & (price < 5000)):
    print(price)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-69-874b8dc1417d> in <module>
# ----> 1 if ((price > '1000') & (price < '5000')):
#       2     print(price)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
